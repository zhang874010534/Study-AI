# %%
def add_number (a,b):
    return a + b

# %%
result  = add_number(3,5)
print("结果是", result)
# Out:
# 结果是 8

# %%
a = float(input("数字1"))
b = float(input("数字2"))
print("结果是", add_number(a,b))
# Out:
# 数字1 1
# 数字2 2
# 结果是 3.0
